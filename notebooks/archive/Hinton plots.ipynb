# %%
# %cd /Users/gwg/local/dmcm
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import torch
from   data import GTExConfig, GTExDataset
import plotutils
# Out:
# /Users/gwg/local/dmcm

# %%
cfg     = GTExConfig()
dataset = GTExDataset(cfg)

# %%
batch_size = 64
offset = np.random.randint(2221 - batch_size)

batch = torch.Tensor(batch_size, 18659)
for i in range(batch_size):
    _, genes = dataset[i+offset]
    batch[i] = genes

np.random.shuffle(batch.numpy())
mat = np.corrcoef(batch.numpy())
plt.imshow(mat)
plt.show()
